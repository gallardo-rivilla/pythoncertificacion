# %% [markdown]
# # Examen 1: Ejercicios de examenes
# ----------------------------------------------------

# %% [markdown]
# ## 🤷‍♂️ Pregunta 1
# ------------------------------------------
#
# ### ¿Cuantos "#" imprime este script?

# %%
lst = [[x for x in range(3)] for y in range (3)]

for r in range (3):
    for c in range (3):
        if lst[r][c] % 2 != 0:
            print("#")
# Out:
# #
# #
# #

# %% [markdown]
# ## 🤷‍♂️ Pregunta 2
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
# a) 1
#
# b) 2
#
# c) El código causaría un error
#
# d) None

# %%
def fun (x):
    if x % 2 == 0:
        return 1
    else: 
        return 2

print(fun(fun(2)))
# Out:
# 2

# %% [markdown]
# ## 🤷‍♂️ Pregunta 3
# ------------------------------------------
#
# ### ¿Qué valor tendría la variable x?
#
# a) True
#
# b) False
#
# c) 0
#
# d) 1

# %%
z = 0
y = 10

x = y < z and z > y or y > z and z < y

x
# Out:
# True

# %% [markdown]
# ## 🤷‍♂️ Pregunta 4
# ------------------------------------------
#
# ### El significado de un argumento posicional es determinado por:
#
# a) los nombres de los argumentos especificados con ese valor
#
# b) la posición sin el argumento de la lista
#
# c) el valor
#
# d) la conexion con las variables existentes

# %% [markdown]
# ## 🤷‍♂️ Pregunta 5
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
# a) 2
#
# b) 6
#
# c) causaría error SyntaxError
#
# d) 4

# %%
def fun(inp=2,out=3):
    return inp * out

print(fun(out=2))
# Out:
# 4

# %% [markdown]
# ## 🤷‍♂️ Pregunta 6
# ------------------------------------------
#
# ### En relación a esta expresión entre tuplas my_tuple[1] = my_tuple[1] + my_tuple[0]
#
# a) es ilegal
#
# b) es totalmente correcta
#
# c) puede ser ejecutado solo si la tupla contiene menos de 2 elementos
#
# d) debe ser ilegal si la tupla contiene strings

# %% [markdown]
# ## 🤷‍♂️ Pregunta 7
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
# a) asepbsepc
#
# b) asepbsepcsep
#
# c) abc
#
# d) a b c

# %%
print("a", "b", "c", sep="sep")
# Out:
# asepbsepc

# %% [markdown]
# ## 🤷‍♂️ Pregunta 8
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
# a) 1 1
#
# b) 0 1
#
# c) 0 0
#
# d) 1 0

# %%
a = 1
b =0

a = a^b
b = a^b
a = a^b

print(a,b)
# Out:
# 0 1

# %% [markdown]
# ## 🤷‍♂️ Pregunta 9
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
# a) one
#
# b) three
#
# c) two
#
# d) ('one', 'two', 'three')

# %%
dct = {'one':'two','three': 'one','two':'three'}
v= dct['three']

for k in range(len(dct)):
    v = dct[v]
    
print(v)
# Out:
# one

# %% [markdown]
# ## 🤷‍♂️ Pregunta 10
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
# a) 0
#
# b) causaria un error runtime
#
# c) 2
#
# d) 1

# %%
def fun(x,y):
    if x==y:
        return x
    else:
        return fun(x,y-1)

print(fun(0,3))
# Out:
# 0

# %% [markdown]
# ## 🤷‍♂️ Pregunta 11
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
# a) vals is mayor que nums
#
# b) causaria un error runtime
#
# c) nums y vals son iguales
#
# d) nums es mayor que vals

# %%
nums = [1,2,3]
vals=nums
del vals[:]

print(nums)
print(vals)
# Out:
# []
# []

# %% [markdown]
# ## 🤷‍♂️ Pregunta 12
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
# a)16
#
# b) causaria un error runtime
#
# c) 4
#
# d) 2

# %%
def function_1(a):
    return None
def function_2(a):
    return function_1(a) * function_1(a)

print(function_2(2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-03b6fc9d31a8> in <module>
#       4     return function_1(a) * function_1(a)
#       5
# ----> 6 print(function_2(2))
#
# <ipython-input-1-03b6fc9d31a8> in function_2(a)
#       2     return None
#       3 def function_2(a):
# ----> 4     return function_1(a) * function_1(a)
#       5
#       6 print(function_2(2))
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'NoneType'

# %% [markdown]
# ## 🤷‍♂️ Pregunta 13
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
# a) 0 1
#
# b) el código es erróneo (el diccionario no tiene el método vals()
#
# c) 0 1
#
# d) 0 0

# %%
dd = {"1": "0", "0": "1"}

for x in dd.vals():
    print(x,end="")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-72637afeab42> in <module>
#       1 dd = {"1": "0", "0": "1"}
#       2
# ----> 3 for x in dd.vals():
#       4     print(x,end="")
#
# AttributeError: 'dict' object has no attribute 'vals'

# %% [markdown]
# ## 🤷‍♂️ Pregunta 14
# ------------------------------------------
#
# ### ¿Cual sería la salida de la siguiente operación? 1 // 2
#
# a) no se puede predecir
#
# b) 0.0
#
# c) 0
#
# d) 0.5

# %%
1 // 2
# Out:
# 0

# %% [markdown]
# ## 🤷‍♂️ Pregunta 15
# ------------------------------------------
#
# ### ¿Cuantas "*" imprime el siguiente script?
#
#
# a) 1
#
# b) loop infinito
#
# c) 0
#
# d) 2

# %%
i = 0
while i < i + 2:
    print("*")
else:
    print("*")
# Out:
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# *
# ...

# %% [markdown]
# ## 🤷‍♂️ Pregunta 16
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
#
# a) [0,1,4,16]
#
# b) [0,1,4,9]
#
# c) [0,1,9,16]
#
# d) [1,4,9,16]

# %%
my_list = [x * x for x in range (5)]

def fun(lst):
    del lst[lst[2]]
    return lst

print(fun(my_list))
# Out:
# [0, 1, 4, 9]

# %% [markdown]
# ## 🤷‍♂️ Pregunta 17
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
#
# a) 0.2
#
# b) 0
#
# c) 0.4
#
# d) 0.0

# %%
x =  1 // 5 + 1 / 5

print(x)
# Out:
# 0.2

# %% [markdown]
# ## 🤷‍♂️ Pregunta 18
# ------------------------------------------
#
# ### ¿Cual de estos nombres de variables es ilegal y causaría un error SyntaxError exception?
#
#
# a) In
#
# b) for
#
# c) print
#
# d) in

# %% [markdown]
# ## 🤷‍♂️ Pregunta 19
# ------------------------------------------
#
# ### ¿Cuantos (#) imprime el siguiente script?
#
#
# a) 3
#
# b) 0
#
# c) 9
#
# d) 6

# %%
lst = [[x for x in range(3)] for y in range(3)]

for r in range (3):
    for c in range(3):
        if lst[r] [c] % 2 !=0:
            print("#")
# Out:
# #
# #
# #

# %% [markdown]
# ## 🤷‍♂️ Pregunta 20
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
#
# a) 4
#
# b) (4,)
#
# c) (4)
#
# d) 44

# %%
tup = (1,2,4,8)
tup = tup[-2:-1]
tup= tup[-1]
print(tup)
# Out:
# 4

# %% [markdown]
# ## 🤷‍♂️ Pregunta 21
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script si el usuario introduce 3 y 6 ?
#
#
# a) 63
#
# b) 6
#
# c) 36
#
# d) 3

# %%
y = input()
x = input()
print(x+y)
# Out:
# 3
# 6
# 63

# %% [markdown]
# ## 🤷‍♂️ Pregunta 22
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
#
# a) 2
#
# b) 4
#
# c) None
#
# d) es erroneo

# %%
def func(a,b):
    return b ** a

print (func(b=2,2))
# Out:
#   File "<ipython-input-15-0c2372fd1ce9>", line 4
#     print (func(b=2,2))
#                     ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ## 🤷‍♂️ Pregunta 23
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
#
# a) ('one','two','three')
#
# b) two
#
# c) one
#
# d) three

# %%
dct = {'one':'two','three':'one','two':'three'}

v= dct['three']

for k in range(len(dct)):
    v=dct[v]
    
print(v)
# Out:
# one

# %% [markdown]
# ## 🤷‍♂️ Pregunta 24
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
#
# a) 2None
#
# b) 2
#
# c) 1
#
# d) causa error runtime

# %%
def fun(x):
    if x % 2 == 0:
        return 1
    else:
        return 2
    
print(fun(fun(2)))
# Out:
# 2

# %% [markdown]
# ## 🤷‍♂️ Pregunta 25
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script si el usuario introduce 3 y 2 ?
#
#
# a) 2
#
# b) 1
#
# c) 3
#
# d) 0

# %%
x = int(input())
y = int(input())

x = x % y
x = x % y
y = y % x

print(y)
# Out:
# 3
# 2
# 0

# %% [markdown]
# ## 🤷‍♂️ Pregunta 26
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
#
# a) [1,2,1,2]
#
# b) [1,2,2,2]
#
# c) [2,1,1,2]
#
# d) [1,1,1,2]

# %%
my_list =[1,2]

for v in range(2):
    my_list.insert(-1,my_list[v])

print(my_list)
# Out:
# [1, 1, 1, 2]

# %% [markdown]
# ## 🤷‍♂️ Pregunta 27
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
#
# a) 4
#
# b) 6
#
# c) error SyntaxError
#
# d) 2

# %%
def fun(inp=2,out=3):
    return inp * out

print(fun(out=2))
# Out:
# 4

# %% [markdown]
# ## 🤷‍♂️ Pregunta 28
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
#
# a) 1 2 2
#
# b) 2 1 2
#
# c) 1 1 2
#
# d) 1 2 1

# %%
x = 1
y = 2
x, y, z = x, x, y
z, y, z = x, y, z

print(x, y, z)
# Out:
# 1 1 2

# %% [markdown]
# ## 🤷‍♂️ Pregunta 29
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
#
# a) (1,2)
#
# b) 21
#
# c) (2,1)
#
# d) 12

# %%
dct = {}

dct['1'] = (1,2)
dct['2'] = (2,1)

for x in dct.keys():
    print(dct[x][1], end="")
# Out:
# 21

# %% [markdown]
# ## 🤷‍♂️ Pregunta 30
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script?
#
#
# a) 3
#
# b) 2
#
# c) 0
#
# d) 1

# %%
lst = [i for i in range(-1,-2)]
lst
# Out:
# []

# %% [markdown]
# ## 🤷‍♂️ Pregunta 31
# ------------------------------------------
#
# ### ¿Cual sería la salida del siguiente script si el usuario introduce 2 y 4 ?
#
#
# a) 2.0
#
# b) 4.0
#
# c) 0.0
#
# d) 1.1

# %%
x = float(input())
y = float(input())

print (y** (1/x))
# Out:
# 2
# 4
# 2.0
